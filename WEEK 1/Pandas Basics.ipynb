# %% [markdown]
# # Pandas Basics

# %% [markdown]
# The table has one row for each album and several columns
#
# - **artist** - Name of the artist
# - **album** - Name of the album
# - **released_year** - Year the album was released
# - **length_min_sec** - Length of the album (hours,minutes,seconds)
# - **genre** - Genre of the album
# - **music_recording_sales_millions** - Music recording sales (millions in USD) on [SONG://DATABASE](http://www.song-database.com/)
# - **claimed_sales_millions** - Album's claimed sales (millions in USD) on [SONG://DATABASE](http://www.song-database.com/)
# - **date_released** - Date on which the album was released
# - **soundtrack** - Indicates if the album is the movie soundtrack (Y) or (N)
# - **rating_of_friends** - Indicates the rating from your friends from 1 to 10
# <br>
#
# You can see the dataset here:
#
# <font size="1">
# <table font-size:xx-small style="width:85%">
#   <tr>
#     <th>Artist</th>
#     <th>Album</th>
#     <th>Released</th>
#     <th>Length</th>
#     <th>Genre</th>
#     <th>Music recording sales (millions)</th>
#     <th>Claimed sales (millions)</th>
#     <th>Released</th>
#     <th>Soundtrack</th>
#     <th>Rating (friends)</th>
#   </tr>
#   <tr>
#     <td>Michael Jackson</td>
#     <td>Thriller</td>
#     <td>1982</td>
#     <td>00:42:19</td>
#     <td>Pop, rock, R&B</td>
#     <td>46</td>
#     <td>65</td>
#     <td>30-Nov-82</td>
#     <td></td>
#     <td>10.0</td>
#   </tr>
#   <tr>
#     <td>AC/DC</td>
#     <td>Back in Black</td>
#     <td>1980</td>
#     <td>00:42:11</td>
#     <td>Hard rock</td>
#     <td>26.1</td>
#     <td>50</td>
#     <td>25-Jul-80</td>
#     <td></td>
#     <td>8.5</td>
#   </tr>
#     <tr>
#     <td>Pink Floyd</td>
#     <td>The Dark Side of the Moon</td>
#     <td>1973</td>
#     <td>00:42:49</td>
#     <td>Progressive rock</td>
#     <td>24.2</td>
#     <td>45</td>
#     <td>01-Mar-73</td>
#     <td></td>
#     <td>9.5</td>
#   </tr>
#     <tr>
#     <td>Whitney Houston</td>
#     <td>The Bodyguard</td>
#     <td>1992</td>
#     <td>00:57:44</td>
#     <td>Soundtrack/R&B, soul, pop</td>
#     <td>26.1</td>
#     <td>50</td>
#     <td>25-Jul-80</td>
#     <td>Y</td>
#     <td>7.0</td>
#   </tr>
#     <tr>
#     <td>Meat Loaf</td>
#     <td>Bat Out of Hell</td>
#     <td>1977</td>
#     <td>00:46:33</td>
#     <td>Hard rock, progressive rock</td>
#     <td>20.6</td>
#     <td>43</td>
#     <td>21-Oct-77</td>
#     <td></td>
#     <td>7.0</td>
#   </tr>
#     <tr>
#     <td>Eagles</td>
#     <td>Their Greatest Hits (1971-1975)</td>
#     <td>1976</td>
#     <td>00:43:08</td>
#     <td>Rock, soft rock, folk rock</td>
#     <td>32.2</td>
#     <td>42</td>
#     <td>17-Feb-76</td>
#     <td></td>
#     <td>9.5</td>
#   </tr>
#     <tr>
#     <td>Bee Gees</td>
#     <td>Saturday Night Fever</td>
#     <td>1977</td>
#     <td>1:15:54</td>
#     <td>Disco</td>
#     <td>20.6</td>
#     <td>40</td>
#     <td>15-Nov-77</td>
#     <td>Y</td>
#     <td>9.0</td>
#   </tr>
#     <tr>
#     <td>Fleetwood Mac</td>
#     <td>Rumours</td>
#     <td>1977</td>
#     <td>00:40:01</td>
#     <td>Soft rock</td>
#     <td>27.9</td>
#     <td>40</td>
#     <td>04-Feb-77</td>
#     <td></td>
#     <td>9.5</td>
#   </tr>
# </table></font>

# %% [markdown]
# <a id="ref1"></a>
# <h2 align=center> Importing Data </h2>

# %% [markdown]
# We can import the libraries  or dependency like Pandas  using the following command:

# %%
import pandas as pd

# %% [markdown]
# After the import command, we now have access to a large number of pre-built classes and functions. This assumes the library is installed; in our lab environment all the necessary libraries are installed. One way pandas allows you to work with data is a dataframe. Let's go through the process to go from a comma separated values (**.csv** ) file to a dataframe. This variable **csv_path** stores the path of the  **.csv** ,that is  used as an argument to the **read_csv** function. The result is stored in the object ** df**, this is a common short form used for a variable referring to a Pandas dataframe.

# %%
df=pd.read_csv('top_selling_albums.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# We can use the method **head()** to examine the first five rows of a dataframe:

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# 2                        45  01-Mar-73        NaN     9.0
# 3                        44  17-Nov-92          Y     8.5
# 4                        43  21-Oct-77        NaN     8.0

# %% [markdown]
# We can use the method **tail()** to examine the last five rows of a dataframe:

# %%
df.tail()
# Out:
#             Artist                            Album  Released   Length  \
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 3                        44  17-Nov-92          Y     8.5
# 4                        43  21-Oct-77        NaN     8.0
# 5                        42  17-Feb-76        NaN     7.5
# 6                        40  15-Nov-77          Y     7.0
# 7                        40  04-Feb-77        NaN     6.5

# %% [markdown]
# We can use the attribute **shape** to examine the number of rows and columns of a dataframe:

# %%
df.shape
# Out:
# (8, 10)

# %% [markdown]
# The process for loading an excel file is similar, we use the path of the excel file and the function **read_excel**. The result is a data frame as before:

# %%
#dependency  needed to install file checking package existance with in environment
#!pip install xlrd
#pd.read_

# %%
df = pd.read_excel('top_selling_albums.xlsx')
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# 2                        45 1973-03-01        NaN     9.0
# 3                        44 1992-11-17          Y     8.5
# 4                        43 1977-10-21        NaN     8.0

# %% [markdown]
# We can access the column "Length" and assign it a new dataframe 'x':

# %%
x=df[['Length']]
x
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33
# 5  00:43:08
# 6  01:15:54
# 7  00:40:01

# %% [markdown]
#  The process is shown in the figure:

# %% [markdown]
# <img src = "https://ibm.box.com/shared/static/bz800py5ui4w0kpb0k09lq3k5oegop5v.png" width = 750, align = "center"></a>

# %% [markdown]
#  <a id="ref2"></a>
# <h2 align=center> Viewing Data and Accessing Data </h2>

# %% [markdown]
# You can also assign the value to a series, you can think of a Pandas series as a 1-D dataframe. Just use one bracket:

# %%
x=df['Length']
y=df[['Artist']]
print(type(y))
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
x
# Out:
# 0    00:42:19
# 1    00:42:11
# 2    00:42:49
# 3    00:57:44
# 4    00:46:33
# 5    00:43:08
# 6    01:15:54
# 7    00:40:01
# Name: Length, dtype: object

# %%
x = df['Rating']
x
# Out:
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5
# Name: Rating, dtype: float64

# %% [markdown]
# You can also assign different columns, for example, we can assign the column 'Artist':

# %%
newvar=df[['Released.1']]
newvar
# Out:
#   Released.1
# 0 1982-11-30
# 1 1980-07-25
# 2 1973-03-01
# 3 1992-11-17
# 4 1977-10-21
# 5 1976-02-17
# 6 1977-11-15
# 7 1977-02-04

# %%
x=df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Assign the variable 'q' to the dataframe that is made up of the column 'Rating':

# %%
#write code here
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %% [markdown]
# You can do the same thing for multiple columns; we just put the dataframe name, in this case, **df**, and the name of the multiple column headers enclosed in double brackets. The result is a new dataframe comprised of the specified columns:

# %%
y=df[['Length','Artist','Genre']]
y
# Out:
#      Length           Artist                        Genre
# 0  00:42:19  Michael Jackson               pop, rock, R&B
# 1  00:42:11            AC/DC                    hard rock
# 2  00:42:49       Pink Floyd             progressive rock
# 3  00:57:44  Whitney Houston               R&B, soul, pop
# 4  00:46:33        Meat Loaf  hard rock, progressive rock
# 5  00:43:08           Eagles   rock, soft rock, folk rock
# 6  01:15:54         Bee Gees                        disco
# 7  00:40:01    Fleetwood Mac                    soft rock

# %% [markdown]
# The process is shown in the figure:

# %% [markdown]
# <img src = "https://ibm.box.com/shared/static/dh9duk3ucuhmmmbixa6ugac6g384m5sq.png" width = 1100, align = "center"></a>

# %%
df[['Album','Released','Length']]
# Out:
#                              Album  Released    Length
# 0                         Thriller      1982  00:42:19
# 1                    Back in Black      1980  00:42:11
# 2        The Dark Side of the Moon      1973  00:42:49
# 3                    The Bodyguard      1992  00:57:44
# 4                  Bat Out of Hell      1977  00:46:33
# 5  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6             Saturday Night Fever      1977  01:15:54
# 7                          Rumours      1977  00:40:01

# %% [markdown]
# #### Assign the variable 'q' to the dataframe that is made up of the column 'Released' and 'Artist':

# %%
q=df[['Released','Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %% [markdown]
# One way to access unique elements is the 'iloc' method, where you can access the 1st row and first column as follows :

# %%
df.loc[0,'Artist']
# Out:
# 'Michael Jackson'

# %%
df.iloc[0:1,:4]
# Out:
#             Artist     Album  Released    Length
# 0  Michael Jackson  Thriller      1982  00:42:19

# %%
df.iloc[0,0:2]
# Out:
# Artist    Michael Jackson
# Album            Thriller
# Name: 0, dtype: object

# %% [markdown]
# Notice something? A series is returned
#
# Let's convert it to table form

# %%
df.iloc[0:2,0:6]
# Out:
#             Artist          Album  Released    Length           Genre  \
# 0  Michael Jackson       Thriller      1982  00:42:19  pop, rock, R&B
# 1            AC/DC  Back in Black      1980  00:42:11       hard rock
#
#    Music Recording Sales (millions)
# 0                              46.0
# 1                              26.1

# %% [markdown]
#  You can access the 1st 2 rows as follows:

# %%
df.iloc[0:2]
# Out:
#             Artist          Album  Released    Length           Genre  \
# 0  Michael Jackson       Thriller      1982  00:42:19  pop, rock, R&B
# 1            AC/DC  Back in Black      1980  00:42:11       hard rock
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 0                              46.0                        65 1982-11-30
# 1                              26.1                        50 1980-07-25
#
#   Soundtrack  Rating
# 0        NaN    10.0
# 1        NaN     9.5

# %% [markdown]
# You can access columns with rows as well:

# %%
df.iloc[0:2,0:2]
# Out:
#             Artist          Album
# 0  Michael Jackson       Thriller
# 1            AC/DC  Back in Black

# %% [markdown]
# There is another method call 'loc' which uses names of row and column indexes.
# Notice that 'iloc' was using row and column index to access values

# %%
df.loc[0:2,['Album']]
# Out:
#                        Album
# 0                   Thriller
# 1              Back in Black
# 2  The Dark Side of the Moon

# %% [markdown]
# Access multiple columns by 'loc'

# %%
df.loc[0:2,['Album','Length']]
# Out:
#                        Album    Length
# 0                   Thriller  00:42:19
# 1              Back in Black  00:42:11
# 2  The Dark Side of the Moon  00:42:49

# %% [markdown]
# #### Access the 4th to 6th row:

# %%
df.iloc[4:6,]
# Out:
#       Artist                            Album  Released    Length  \
# 4  Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5     Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
#
#                          Genre  Music Recording Sales (millions)  \
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 4                        43 1977-10-21        NaN     8.0
# 5                        42 1976-02-17        NaN     7.5

# %% [markdown]
# Trying with iloc it would be

# %%
df.loc[4:5]
# Out:
#       Artist                            Album  Released    Length  \
# 4  Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5     Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
#
#                          Genre  Music Recording Sales (millions)  \
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating New Artist
# 4                        43 1977-10-21        NaN     8.0  Meat Loaf
# 5                        42 1976-02-17        NaN     7.5     Eagles

# %% [markdown]
# #### Access 5th and rows after 5th with columns starting from Artist till Length

# %%
df.loc[5:,:'Length']
# Out:
#           Artist                            Album  Released    Length
# 5         Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6       Bee Gees             Saturday Night Fever      1977  01:15:54
# 7  Fleetwood Mac                          Rumours      1977  00:40:01

# %% [markdown]
# Using iloc

# %%
df.iloc[5:,:4]
# Out:
#           Artist                            Album  Released    Length
# 5         Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6       Bee Gees             Saturday Night Fever      1977  01:15:54
# 7  Fleetwood Mac                          Rumours      1977  00:40:01

# %% [markdown]
# ## Adding Column

# %%
df['New Artist'] = df['Artist']

# %%
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating       New Artist
# 0                        65 1982-11-30        NaN    10.0  Michael Jackson
# 1                        50 1980-07-25        NaN     9.5            AC/DC
# 2                        45 1973-03-01        NaN     9.0       Pink Floyd
# 3                        44 1992-11-17          Y     8.5  Whitney Houston
# 4                        43 1977-10-21        NaN     8.0        Meat Loaf

# %% [markdown]
# ## Droping Column

# %%
df.drop(['New Artist'], axis=1, inplace=True)
#single label or list-like
#    Index or column labels to drop
#axis = 0 row
#axis = 1 column
#inplace = True means u want to delete data permenatly (return fuction)
        #False then its become (no return fuction)

# %%
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# 2                        45 1973-03-01        NaN     9.0
# 3                        44 1992-11-17          Y     8.5
# 4                        43 1977-10-21        NaN     8.0

# %%
df.columns
# Out:
# Index(['Artist', 'Album', 'Released', 'Length', 'Genre',
#        'Music Recording Sales (millions)', 'Claimed Sales (millions)',
#        'Released.1', 'Soundtrack', 'Rating'],
#       dtype='object')

# %% [markdown]
# ## Object Type of each column

# %%
df.dtypes
#its very import in data cleaning
#like Released.1     (datetime64[ns] )we know but if it datatype show object then something wrong is enter "1982-11-30?"
#in pandas the string as called object 
#Artist                                      object
#Album                                       object
# Out:
# Artist                                      object
# Album                                       object
# Released                                     int64
# Length                                      object
# Genre                                       object
# Music Recording Sales (millions)           float64
# Claimed Sales (millions)                     int64
# Released.1                          datetime64[ns]
# Soundtrack                                  object
# Rating                                     float64
# dtype: object

# %% [markdown]
# ## Null values check in Data Frame

# %%
df.isnull()
#boolen function
# Out:
#    Artist  Album  Released  Length  Genre  Music Recording Sales (millions)  \
# 0   False  False     False   False  False                             False
# 1   False  False     False   False  False                             False
# 2   False  False     False   False  False                             False
# 3   False  False     False   False  False                             False
# 4   False  False     False   False  False                             False
# 5   False  False     False   False  False                             False
# 6   False  False     False   False  False                             False
# 7   False  False     False   False  False                             False
#
#    Claimed Sales (millions)  Released.1  Soundtrack  Rating
# 0                     False       False        True   False
# 1                     False       False        True   False
# 2                     False       False        True   False
# 3                     False       False       False   False
# 4                     False       False        True   False
# 5                     False       False        True   False
# 6                     False       False       False   False
# 7                     False       False        True   False

# %%
df.isnull().sum()
# Out:
# Artist                              0
# Album                               0
# Released                            0
# Length                              0
# Genre                               0
# Music Recording Sales (millions)    0
# Claimed Sales (millions)            0
# Released.1                          0
# Soundtrack                          6
# Rating                              0
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
df.describe()
# Out:
#           Released  Music Recording Sales (millions)  \
# count     8.000000                          8.000000
# mean   1979.250000                         28.125000
# std       5.800246                          8.189322
# min    1973.000000                         20.600000
# 25%    1976.750000                         23.300000
# 50%    1977.000000                         26.750000
# 75%    1980.500000                         28.975000
# max    1992.000000                         46.000000
#
#        Claimed Sales (millions)     Rating
# count                  8.000000   8.000000
# mean                  46.125000   8.250000
# std                    8.271077   1.224745
# min                   40.000000   6.500000
# 25%                   41.500000   7.375000
# 50%                   43.500000   8.250000
# 75%                   46.250000   9.125000
# max                   65.000000  10.000000

# %%
df.describe(include='all')
# Out:
#         Artist                      Album     Released    Length  \
# count        8                          8     8.000000         8
# unique       8                          8          NaN         8
# top     Eagles  The Dark Side of the Moon          NaN  00:40:01
# freq         1                          1          NaN         1
# first      NaN                        NaN          NaN       NaN
# last       NaN                        NaN          NaN       NaN
# mean       NaN                        NaN  1979.250000       NaN
# std        NaN                        NaN     5.800246       NaN
# min        NaN                        NaN  1973.000000       NaN
# 25%        NaN                        NaN  1976.750000       NaN
# 50%        NaN                        NaN  1977.000000       NaN
# 75%        NaN                        NaN  1980.500000       NaN
# max        NaN                        NaN  1992.000000       NaN
#
#                              Genre  Music Recording Sales (millions)  \
# count                            8                          8.000000
# unique                           8                               NaN
# top     rock, soft rock, folk rock                               NaN
# freq                             1                               NaN
# first                          NaN                               NaN
# last                           NaN                               NaN
# mean                           NaN                         28.125000
# std                            NaN                          8.189322
# min                            NaN                         20.600000
# 25%                            NaN                         23.300000
# 50%                            NaN                         26.750000
# 75%                            NaN                         28.975000
# max                            NaN                         46.000000
#
#         Claimed Sales (millions)           Released.1 Soundtrack     Rating
# count                   8.000000                    8          2   8.000000
# unique                       NaN                    8          1        NaN
# top                          NaN  1977-11-15 00:00:00          Y        NaN
# freq                         NaN                    1          2        NaN
# first                        NaN  1973-03-01 00:00:00        NaN        NaN
# last                         NaN  1992-11-17 00:00:00        NaN        NaN
# mean                   46.125000                  NaN        NaN   8.250000
# std                     8.271077                  NaN        NaN   1.224745
# min                    40.000000                  NaN        NaN   6.500000
# 25%                    41.500000                  NaN        NaN   7.375000
# 50%                    43.500000                  NaN        NaN   8.250000
# 75%                    46.250000                  NaN        NaN   9.125000
# max                    65.000000                  NaN        NaN  10.000000

# %%
df.describe(include='O')
# Out:
#           Artist                 Album    Length                        Genre  \
# count          8                     8         8                            8
# unique         8                     8         8                            8
# top     Bee Gees  Saturday Night Fever  00:42:19  hard rock, progressive rock
# freq           1                     1         1                            1
#
#        Soundtrack
# count           2
# unique          1
# top             Y
# freq            2

# %% [markdown]
# ## Querying a dataframe

# %% [markdown]
# Querying a database means finding some values based on certain conditions. For example you want to find out the albums having rating greater and equal to 9

# %%
df['Rating']
# Out:
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5
# Name: Rating, dtype: float64

# %%
df['Rating']>9
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Rating, dtype: bool

# %%
df[['Rating']]
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
df.loc[1:,['Album']]
# Out:
#                              Album
# 1                    Back in Black
# 2        The Dark Side of the Moon
# 3                    The Bodyguard
# 4                  Bat Out of Hell
# 5  Their Greatest Hits (1971-1975)
# 6             Saturday Night Fever
# 7                          Rumours

# %%
df[df['Rating']>=9]
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
#
#               Genre  Music Recording Sales (millions)  \
# 0    pop, rock, R&B                              46.0
# 1         hard rock                              26.1
# 2  progressive rock                              24.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# 2                        45 1973-03-01        NaN     9.0

# %%
soundtracks= df[df['Rating']<7]

# %%
soundtracks
# Out:
#           Artist    Album  Released    Length      Genre  \
# 7  Fleetwood Mac  Rumours      1977  00:40:01  soft rock
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 7                              27.9                        40 1977-02-04
#
#   Soundtrack  Rating
# 7        NaN     6.5

# %% [markdown]
# Notice that in the above result all the columns are displayed. If you want to access a specific column, then you can use **loc** for that purpose.

# %%
df['Rating']>=8.0
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# Name: Rating, dtype: bool

# %%
soundtracks_album= df.loc[df['Rating']>=8.0, ['Album']]

# %%
soundtracks_album
# Out:
#                        Album
# 0                   Thriller
# 1              Back in Black
# 2  The Dark Side of the Moon
# 3              The Bodyguard
# 4            Bat Out of Hell

# %% [markdown]
# ### Task

# %% [markdown]
# Find out the albums released during and after the year 1980

# %%
# write code here
df['Released']
# Out:
# 0    1982
# 1    1980
# 2    1973
# 3    1992
# 4    1977
# 5    1976
# 6    1977
# 7    1977
# Name: Released, dtype: int64

# %%
df['Released']>1980
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Released, dtype: bool

# %%
df[df['Released']>1980]
# Out:
#             Artist          Album  Released    Length           Genre  \
# 0  Michael Jackson       Thriller      1982  00:42:19  pop, rock, R&B
# 3  Whitney Houston  The Bodyguard      1992  00:57:44  R&B, soul, pop
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 0                              46.0                        65 1982-11-30
# 3                              27.4                        44 1992-11-17
#
#   Soundtrack  Rating
# 0        NaN    10.0
# 3          Y     8.5

# %%
df.loc[df['Released']>=1980,['Album']]
# Out:
#            Album
# 0       Thriller
# 1  Back in Black
# 3  The Bodyguard

# %% [markdown]
# # Exercise
#
# Import file **cars.csv** and show following:
#
#     1.) Top five rows
#     2.) Last five rows
#     3.) No. of rows and columns
#     4.) Access 100th to 130th row with any 3 columns
#     5.) Object types of each column
#     6.) Null values count in each column
#     7.) Summary Statistics

# %%
#importing the file
df_cars=pd.read_csv('cars.csv')

# %%
#top 5 rows
df_cars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
# 3          109         mpfi  3.19    3.40              10.0      102.0
# 4          136         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg  price
# 0    5000.0       21           27  13495
# 1    5000.0       21           27  16500
# 2    5000.0       19           26  16500
# 3    5500.0       24           30  13950
# 4    5500.0       18           22  17450
#
# [5 rows x 26 columns]

# %%
#last 5 rows
df_cars.tail()
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 196         -1               95.0  volvo       gas        std         four
# 197         -1               95.0  volvo       gas      turbo         four
# 198         -1               95.0  volvo       gas        std         four
# 199         -1               95.0  volvo    diesel      turbo         four
# 200         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 196      sedan          rwd           front       109.1  ...            141
# 197      sedan          rwd           front       109.1  ...            141
# 198      sedan          rwd           front       109.1  ...            173
# 199      sedan          rwd           front       109.1  ...            145
# 200      sedan          rwd           front       109.1  ...            141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 196         mpfi  3.78    3.15               9.5      114.0    5400.0
# 197         mpfi  3.78    3.15               8.7      160.0    5300.0
# 198         mpfi  3.58    2.87               8.8      134.0    5500.0
# 199          idi  3.01    3.40              23.0      106.0    4800.0
# 200         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg  price
# 196       23           28  16845
# 197       19           25  19045
# 198       18           23  21485
# 199       26           27  22470
# 200       19           25  22625
#
# [5 rows x 26 columns]

# %%
#Access 100th to 130th row with any 3 columns
df_cars.iloc[100:130,3:4]
# Out:
#     fuel-type
# 100       gas
# 101       gas
# 102       gas
# 103       gas
# 104       gas
# 105    diesel
# 106       gas
# 107    diesel
# 108       gas
# 109    diesel
# 110       gas
# 111    diesel
# 112       gas
# 113    diesel
# 114       gas
# 115       gas
# 116       gas
# 117       gas
# 118       gas
# 119       gas
# 120       gas
# 121       gas
# 122       gas
# 123       gas
# 124       gas
# 125       gas
# 126       gas
# 127       gas
# 128       gas
# 129       gas

# %%
# object types of each column
df_cars.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
#Null values count in each column
df_cars.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#Summary statistics
df_cars.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015  174.200995   65.889055
# std      1.254802           31.99625    6.066366   12.322175    2.101471
# min     -2.000000           65.00000   86.600000  141.100000   60.300000
# 25%      0.000000          101.00000   94.500000  166.800000   64.100000
# 50%      1.000000          122.00000   97.000000  173.200000   65.500000
# 75%      2.000000          137.00000  102.400000  183.500000   66.600000
# max      3.000000          256.00000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256874
# std      2.447822   517.296727    41.546834    0.268072    0.316048
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price
# count    201.000000
# mean   13207.129353
# std     7947.066342
# min     5118.000000
# 25%     7775.000000
# 50%    10295.000000
# 75%    16500.000000
# max    45400.000000

# %%
df_cars.describe(include='O')
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %% [markdown]
# # Grouping

# %% [markdown]
# Grouping works similar to "group by" as in databases. Pandas also provides a "group by" function which serves the same purpose.

# %%
df_cars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
# 3          109         mpfi  3.19    3.40              10.0      102.0
# 4          136         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg  price
# 0    5000.0       21           27  13495
# 1    5000.0       21           27  16500
# 2    5000.0       19           26  16500
# 3    5500.0       24           30  13950
# 4    5500.0       18           22  17450
#
# [5 rows x 26 columns]

# %%
df_cars.groupby('fuel-type')['price'].mean()
# Out:
# fuel-type
# diesel    15838.15000
# gas       12916.40884
# Name: price, dtype: float64

# %%
#value_counts()   Ascending order series method
#count()  used by groupby DataFrame

# %%
t = df_cars['make'].value_counts()
t
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# isuzu             2
# mercury           1
# Name: make, dtype: int64

# %%
df_cars['make'].value_counts(normalize=True)
# Out:
# toyota           0.159204
# nissan           0.089552
# mazda            0.084577
# honda            0.064677
# mitsubishi       0.064677
# volkswagen       0.059701
# subaru           0.059701
# peugot           0.054726
# volvo            0.054726
# dodge            0.044776
# mercedes-benz    0.039801
# bmw              0.039801
# plymouth         0.034826
# saab             0.029851
# audi             0.029851
# porsche          0.019900
# alfa-romero      0.014925
# chevrolet        0.014925
# jaguar           0.014925
# renault          0.009950
# isuzu            0.009950
# mercury          0.004975
# Name: make, dtype: float64

# %%
t.value_counts()
# Out:
# 3     3
# 13    2
# 12    2
# 11    2
# 8     2
# 6     2
# 2     2
# 18    1
# 17    1
# 9     1
# 7     1
# 4     1
# 1     1
# 32    1
# Name: make, dtype: int64

# %%
df_cars['make'].value_counts(normalize=True)[:5]
# Out:
# toyota        0.159204
# nissan        0.089552
# mazda         0.084577
# honda         0.064677
# mitsubishi    0.064677
# Name: make, dtype: float64

# %%
df_cars['make'].value_counts(normalize=True).reset_index()[:5]
# Out:
#         index      make
# 0      toyota  0.159204
# 1      nissan  0.089552
# 2       mazda  0.084577
# 3       honda  0.064677
# 4  mitsubishi  0.064677

# %%
df_cars.groupby('fuel-type')['price'].mean().reset_index()
# Out:
#   fuel-type        price
# 0    diesel  15838.15000
# 1       gas  12916.40884

# %%
fuel_price=df_cars.groupby('fuel-type')['price'].mean()

# %%
fuel_price
# Out:
# fuel-type
# diesel    15838.15000
# gas       12916.40884
# Name: price, dtype: float64

# %%
door_price=df_cars.groupby('num-of-doors')['price'].mean()
door_price
# Out:
# num-of-doors
# four    13498.034783
# two     12818.127907
# Name: price, dtype: float64

# %%
door_price=df_cars.groupby('num-of-doors')['price'].mean().reset_index()
door_price
# Out:
#   num-of-doors         price
# 0         four  13498.034783
# 1          two  12818.127907

# %%
door_price.count()
# Out:
# 2

# %%
door_price.reset_index()
# Out:
#   num-of-doors         price
# 0         four  13498.034783
# 1          two  12818.127907

# %%
door_price.reset_index().reset_index()
# Out:
#    index num-of-doors         price
# 0      0         four  13498.034783
# 1      1          two  12818.127907

# %%
door_price.reset_index().reset_index().reset_index()
# Out:
#    level_0  index num-of-doors         price
# 0        0      0         four  13498.034783
# 1        1      1          two  12818.127907

# %%
group=df_cars.groupby(['fuel-type','num-of-doors'])['price'].mean().reset_index()

# %%
group
# Out:
#   fuel-type num-of-doors         price
# 0    diesel         four  16100.764706
# 1    diesel          two  14350.000000
# 2       gas         four  13046.540816
# 3       gas          two  12762.759036

# %% [markdown]
# ### Task
#
# Find the total price according to each body style.
#
# Hint: use <code>sum()</code> instead of <code>mean</code>.

# %%
# write the code here

df_cars['body-style']
# Out:
# 0      convertible
# 1      convertible
# 2        hatchback
# 3            sedan
# 4            sedan
# 5            sedan
# 6            sedan
# 7            wagon
# 8            sedan
# 9            sedan
# 10           sedan
# 11           sedan
# 12           sedan
# 13           sedan
# 14           sedan
# 15           sedan
# 16           sedan
# 17       hatchback
# 18       hatchback
# 19           sedan
# 20       hatchback
# 21       hatchback
# 22       hatchback
# 23       hatchback
# 24           sedan
# 25           sedan
# 26           sedan
# 27           wagon
# 28       hatchback
# 29       hatchback
#           ...
# 171      hatchback
# 172          sedan
# 173      hatchback
# 174      hatchback
# 175      hatchback
# 176          sedan
# 177          wagon
# 178          sedan
# 179          sedan
# 180          sedan
# 181          sedan
# 182          sedan
# 183          sedan
# 184          sedan
# 185    convertible
# 186      hatchback
# 187          sedan
# 188          sedan
# 189          wagon
# 190          sedan
# 191          wagon
# 192          sedan
# 193          wagon
# 194          sedan
# 195          wagon
# 196          sedan
# 197          sedan
# 198          sedan
# 199          sedan
# 200          sedan
# Name: body-style, Length: 201, dtype: object

# %%
df_cars['body-style'].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
door_price=df_cars.groupby('body-style')['price'].sum()
door_price
# Out:
# body-style
# convertible     131343
# hardtop         177668
# hatchback       677106
# sedan          1359217
# wagon           309299
# Name: price, dtype: int64

# %%
door_price.reset_index()
# Out:
#     body-style    price
# 0  convertible   131343
# 1      hardtop   177668
# 2    hatchback   677106
# 3        sedan  1359217
# 4        wagon   309299

# %%
door_price=df_cars.groupby('body-style')['price'].sum()
door_price
# Out:
# body-style
# convertible     131343
# hardtop         177668
# hatchback       677106
# sedan          1359217
# wagon           309299
# Name: price, dtype: int64

# %%
group=df_cars.groupby(['fuel-type','num-of-doors'])['price'].mean().reset_index()
group
# Out:
#   fuel-type num-of-doors         price
# 0    diesel         four  16100.764706
# 1    diesel          two  14350.000000
# 2       gas         four  13046.540816
# 3       gas          two  12762.759036

# %% [markdown]
# # Pivoting and Melting

# %% [markdown]
# **Pivoting**

# %%
pivoted= pd.pivot_table(df_cars,index='fuel-type',columns='num-of-doors', values='price',aggfunc='mean',fill_value=0)

# %%
pivoted
# Out:
# num-of-doors          four           two
# fuel-type
# diesel        16100.764706  14350.000000
# gas           13046.540816  12762.759036

# %%
new= pivoted.reset_index()

# %%
new
# Out:
# num-of-doors fuel-type          four           two
# 0               diesel  16100.764706  14350.000000
# 1                  gas  13046.540816  12762.759036

# %% [markdown]
# **Melting**

# %%
melted= pd.melt(new,id_vars='fuel-type', value_name='Mean Price')

# %%
melted
# Out:
#   fuel-type num-of-doors    Mean Price
# 0    diesel         four  16100.764706
# 1       gas         four  13046.540816
# 2    diesel          two  14350.000000
# 3       gas          two  12762.759036
